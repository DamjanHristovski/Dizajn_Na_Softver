# %%
import csv
import re
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By

def company_names():
    # Define the URL to scrape company codes
    url = "https://www.mse.mk/mk/stats/symbolhistory/kmb"
    print(f"Accessing URL: {url}")
    
    # Set up the Chrome WebDriver with headless option
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    driver = webdriver.Chrome(options=chrome_options)
    
    try:
        # Open the page
        driver.get(url)
        print("Page loaded successfully.")

        # Find the dropdown and get the company codes
        print("Locating dropdown by ID 'Code'...")
        select_element = Select(driver.find_element(By.ID, "Code"))
        company_codes = [option.get_attribute("value") for option in select_element.options if 
                         option.get_attribute("value") and not re.search(r'\d', option.get_attribute("value"))]
        print(f"Found {len(company_codes)} company codes: {company_codes}")
        
        # Prepare a list to store company data (ID, code, name)
        companies = []

        # Loop through each company code with an ID starting from 1
        for index, code in enumerate(company_codes, start=1):
            print(f"Processing company code {code} (ID: {index})...")
            company_url = f"https://www.mse.mk/mk/symbol/{code}"
            print(f"Navigating to {company_url}...")
            driver.get(company_url)

            # Check if the page redirects to a company page (like Komercijalna Banka)
            if "issuer" in driver.current_url:
                print("Detected 'issuer' in URL.")
                try:
                    company_name = driver.find_element(By.CSS_SELECTOR, "div#izdavach div.col-md-8.title").text
                    print(f"Extracted company name: {company_name}")
                except Exception as e:
                    print(f"Error extracting company name (structure 1): {e}")
                    company_name = "Name not found"
            else:
                print("No 'issuer' in URL. Attempting alternative structure...")
                try:
                    raw_name = driver.find_element(By.ID, "titleKonf2011").text
                    print(f"Raw company name: {raw_name}")  # Debugging: Print raw company name
                    company_name = raw_name.split(" - ", 2)[-1] if " - " in raw_name else raw_name
                    print(f"Processed company name: {company_name}")  # Debugging: Print processed name
                except Exception as e:
                    print(f"Error extracting company name (structure 2): {e}")
                    company_name = "Name not found"
            
            # Add the company ID, code, and name to the list
            companies.append([index, code, company_name])
        
              # Ensure the directory exists
            output_dir = "stockapp/data"
            os.makedirs(output_dir, exist_ok=True)  # Create the directory if it doesn't exist
            output_file = os.path.abspath(f"{output_dir}/company_codes_and_names.csv")
            
            # Print the file location
            print(f"Saving data to: {output_file}")
            with open(output_file, mode='w', newline='', encoding='utf-8') as file:
                writer = csv.writer(file)
                writer.writerow(["Company ID", "Company Code", "Company Name"])  # Write the header
                writer.writerows(companies)  # Write the company data

    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        # Quit the driver
        driver.quit()
        print("Web driver closed.")

# Run the function to scrape and save the data
company_names()
# Out:
# Accessing URL: https://www.mse.mk/mk/stats/symbolhistory/kmb
# Page loaded successfully.
# Locating dropdown by ID 'Code'...
# Found 171 company codes: ['ADIN', 'ALK', 'ALKB', 'AMBR', 'AMEH', 'APTK', 'ATPP', 'AUMK', 'BANA', 'BGOR', 'BIKF', 'BIM', 'BLTU', 'CBNG', 'CDHV', 'CEVI', 'CKB', 'CKBKO', 'DEBA', 'DIMI', 'EDST', 'ELMA', 'ELNC', 'ENER', 'ENSA', 'EUHA', 'EUMK', 'EVRO', 'FAKM', 'FERS', 'FKTL', 'FROT', 'FUBT', 'GALE', 'GDKM', 'GECK', 'GECT', 'GIMS', 'GRDN', 'GRNT', 'GRSN', 'GRZD', 'GTC', 'GTRG', 'IJUG', 'INB', 'INDI', 'INEK', 'INHO', 'INOV', 'INPR', 'INTP', 'JAKO', 'JULI', 'JUSK', 'KARO', 'KDFO', 'KJUBI', 'KKFI', 'KKST', 'KLST', 'KMB', 'KMPR', 'KOMU', 'KONF', 'KONZ', 'KORZ', 'KPSS', 'KULT', 'KVAS', 'LAJO', 'LHND', 'LOTO', 'LOZP', 'MAGP', 'MAKP', 'MAKS', 'MB', 'MERM', 'MKSD', 'MLKR', 'MODA', 'MPOL', 'MPT', 'MPTE', 'MTUR', 'MZHE', 'MZPU', 'NEME', 'NOSK', 'OBPP', 'OILK', 'OKTA', 'OMOS', 'OPFO', 'OPTK', 'ORAN', 'OSPO', 'OTEK', 'PELK', 'PGGV', 'PKB', 'POPK', 'PPIV', 'PROD', 'PROT', 'PTRS', 'RADE', 'REPL', 'RIMI', 'RINS', 'RZEK', 'RZIT', 'RZIZ', 'RZLE', 'RZLV', 'RZTK', 'RZUG', 'RZUS', 'SBT', 'SDOM', 'SIL', 'SKON', 'SKP', 'SLAV', 'SNBT', 'SNBTO', 'SOLN', 'SPAZ', 'SPAZP', 'SPOL', 'SSPR', 'STB', 'STBP', 'STIL', 'STOK', 'TAJM', 'TASK', 'TBKO', 'TEAL', 'TEHN', 'TEL', 'TETE', 'TIGA', 'TIKV', 'TKPR', 'TKVS', 'TNB', 'TRDB', 'TRPS', 'TRUB', 'TSMP', 'TSZS', 'TTK', 'UNI', 'USJE', 'VARG', 'VFPM', 'VITA', 'VROS', 'VSC', 'VTKS', 'ZAS', 'ZILU', 'ZILUP', 'ZIMS', 'ZKAR', 'ZPKO', 'ZPOG', 'ZSIL', 'ZUAS']
# Processing company code ADIN (ID: 1)...
# Navigating to https://www.mse.mk/mk/symbol/ADIN...
# Detected 'issuer' in URL.
# Extracted company name: Адинг АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ALK (ID: 2)...
# Navigating to https://www.mse.mk/mk/symbol/ALK...
# Detected 'issuer' in URL.
# Extracted company name: Алкалоид АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ALKB (ID: 3)...
# Navigating to https://www.mse.mk/mk/symbol/ALKB...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - ALKB - Алкалоид Берово
# Processed company name: Алкалоид Берово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code AMBR (ID: 4)...
# Navigating to https://www.mse.mk/mk/symbol/AMBR...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - AMBR - АМ Брокер АД Скопје
# Processed company name: АМ Брокер АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code AMEH (ID: 5)...
# Navigating to https://www.mse.mk/mk/symbol/AMEH...
# Detected 'issuer' in URL.
# Extracted company name: Агромеханика АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code APTK (ID: 6)...
# Navigating to https://www.mse.mk/mk/symbol/APTK...
# Detected 'issuer' in URL.
# Extracted company name: Ангропромет Тиквешанка АД Кавадарци
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ATPP (ID: 7)...
# Navigating to https://www.mse.mk/mk/symbol/ATPP...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - ATPP - АТП Пролетер Крива Паланка
# Processed company name: АТП Пролетер Крива Паланка
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code AUMK (ID: 8)...
# Navigating to https://www.mse.mk/mk/symbol/AUMK...
# Detected 'issuer' in URL.
# Extracted company name: Аутомакедонија АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code BANA (ID: 9)...
# Navigating to https://www.mse.mk/mk/symbol/BANA...
# Detected 'issuer' in URL.
# Extracted company name: Рудници Бањани АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code BGOR (ID: 10)...
# Navigating to https://www.mse.mk/mk/symbol/BGOR...
# Detected 'issuer' in URL.
# Extracted company name: Кристал 1923 АД Велес
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code BIKF (ID: 11)...
# Navigating to https://www.mse.mk/mk/symbol/BIKF...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - BIKF - Текстил Елма АД Прилеп
# Processed company name: Текстил Елма АД Прилеп
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code BIM (ID: 12)...
# Navigating to https://www.mse.mk/mk/symbol/BIM...
# Detected 'issuer' in URL.
# Extracted company name: БИМ АД Свети Николе
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code BLTU (ID: 13)...
# Navigating to https://www.mse.mk/mk/symbol/BLTU...
# Detected 'issuer' in URL.
# Extracted company name: Благој Туфанов АД Радовиш - долгорочно суспендирано од котација
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code CBNG (ID: 14)...
# Navigating to https://www.mse.mk/mk/symbol/CBNG...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - CBNG - Црвени брегови Неготино
# Processed company name: Црвени брегови Неготино
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code CDHV (ID: 15)...
# Navigating to https://www.mse.mk/mk/symbol/CDHV...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - CDHV - Централен депозитар за хартии од вредност АД Скопј
# Processed company name: Централен депозитар за хартии од вредност АД Скопј
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code CEVI (ID: 16)...
# Navigating to https://www.mse.mk/mk/symbol/CEVI...
# Detected 'issuer' in URL.
# Extracted company name: ФЗЦ 11-ти ОКТОМВРИ АД Куманово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code CKB (ID: 17)...
# Navigating to https://www.mse.mk/mk/symbol/CKB...
# Detected 'issuer' in URL.
# Extracted company name: Централна кооперативна банка АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code CKBKO (ID: 18)...
# Navigating to https://www.mse.mk/mk/symbol/CKBKO...
# Detected 'issuer' in URL.
# Extracted company name: Централна кооперативна банка АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code DEBA (ID: 19)...
# Navigating to https://www.mse.mk/mk/symbol/DEBA...
# Detected 'issuer' in URL.
# Extracted company name: Дебарски Бањи –Цапа АД Дебар
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code DIMI (ID: 20)...
# Navigating to https://www.mse.mk/mk/symbol/DIMI...
# Detected 'issuer' in URL.
# Extracted company name: Димко Митрев АД Велес
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code EDST (ID: 21)...
# Navigating to https://www.mse.mk/mk/symbol/EDST...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - EDST - Единство Струга
# Processed company name: Единство Струга
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ELMA (ID: 22)...
# Navigating to https://www.mse.mk/mk/symbol/ELMA...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - ELMA - Елмар Штип
# Processed company name: Елмар Штип
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ELNC (ID: 23)...
# Navigating to https://www.mse.mk/mk/symbol/ELNC...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - ELNC - Еленица Струмица
# Processed company name: Еленица Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ENER (ID: 24)...
# Navigating to https://www.mse.mk/mk/symbol/ENER...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - ENER - Енергомонт Скопје
# Processed company name: Енергомонт Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ENSA (ID: 25)...
# Navigating to https://www.mse.mk/mk/symbol/ENSA...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - ENSA - Флекс брокер АД Скопје
# Processed company name: Флекс брокер АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code EUHA (ID: 26)...
# Navigating to https://www.mse.mk/mk/symbol/EUHA...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - EUHA - Еурохаус АД Скопје
# Processed company name: Еурохаус АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code EUMK (ID: 27)...
# Navigating to https://www.mse.mk/mk/symbol/EUMK...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - EUMK - Еуромак брокер АД Скопје
# Processed company name: Еуромак брокер АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code EVRO (ID: 28)...
# Navigating to https://www.mse.mk/mk/symbol/EVRO...
# Detected 'issuer' in URL.
# Extracted company name: Европа АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code FAKM (ID: 29)...
# Navigating to https://www.mse.mk/mk/symbol/FAKM...
# Detected 'issuer' in URL.
# Extracted company name: ФАКОМ АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code FERS (ID: 30)...
# Navigating to https://www.mse.mk/mk/symbol/FERS...
# Detected 'issuer' in URL.
# Extracted company name: Фершпед АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code FKTL (ID: 31)...
# Navigating to https://www.mse.mk/mk/symbol/FKTL...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - FKTL - ФК Струга-Трим-Лум АД Струга
# Processed company name: ФК Струга-Трим-Лум АД Струга
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code FROT (ID: 32)...
# Navigating to https://www.mse.mk/mk/symbol/FROT...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - FROT - Фротирка компани АД Делчево
# Processed company name: Фротирка компани АД Делчево
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code FUBT (ID: 33)...
# Navigating to https://www.mse.mk/mk/symbol/FUBT...
# Detected 'issuer' in URL.
# Extracted company name: Фустеларко Борец АД Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GALE (ID: 34)...
# Navigating to https://www.mse.mk/mk/symbol/GALE...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - GALE - Галеб Охрид
# Processed company name: Галеб Охрид
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GDKM (ID: 35)...
# Navigating to https://www.mse.mk/mk/symbol/GDKM...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - GDKM - ЗИК Градиште Куманово
# Processed company name: ЗИК Градиште Куманово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GECK (ID: 36)...
# Navigating to https://www.mse.mk/mk/symbol/GECK...
# Detected 'issuer' in URL.
# Extracted company name: Герас Цунев Конфекција АД Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GECT (ID: 37)...
# Navigating to https://www.mse.mk/mk/symbol/GECT...
# Detected 'issuer' in URL.
# Extracted company name: Герас Цунев Трговија АД Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GIMS (ID: 38)...
# Navigating to https://www.mse.mk/mk/symbol/GIMS...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - GIMS - Градежен институт Македонија АД Скопје
# Processed company name: Градежен институт Македонија АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GRDN (ID: 39)...
# Navigating to https://www.mse.mk/mk/symbol/GRDN...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - GRDN - Градинар АД Охрид
# Processed company name: Градинар АД Охрид
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GRNT (ID: 40)...
# Navigating to https://www.mse.mk/mk/symbol/GRNT...
# Detected 'issuer' in URL.
# Extracted company name: Гранит АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GRSN (ID: 41)...
# Navigating to https://www.mse.mk/mk/symbol/GRSN...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - GRSN - Градинар Свети Николе
# Processed company name: Градинар Свети Николе
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GRZD (ID: 42)...
# Navigating to https://www.mse.mk/mk/symbol/GRZD...
# Detected 'issuer' in URL.
# Extracted company name: Грозд АД Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GTC (ID: 43)...
# Navigating to https://www.mse.mk/mk/symbol/GTC...
# Detected 'issuer' in URL.
# Extracted company name: ГТЦ АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code GTRG (ID: 44)...
# Navigating to https://www.mse.mk/mk/symbol/GTRG...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - GTRG - Гетро Гостивар
# Processed company name: Гетро Гостивар
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code IJUG (ID: 45)...
# Navigating to https://www.mse.mk/mk/symbol/IJUG...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - IJUG - Институт за заварув. Југ Скопје
# Processed company name: Институт за заварув. Југ Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code INB (ID: 46)...
# Navigating to https://www.mse.mk/mk/symbol/INB...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - INB - Шпаркасе банка Македонија АД Скопје
# Processed company name: Шпаркасе банка Македонија АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code INDI (ID: 47)...
# Navigating to https://www.mse.mk/mk/symbol/INDI...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - INDI - Инекс Дрим АД Струга
# Processed company name: Инекс Дрим АД Струга
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code INEK (ID: 48)...
# Navigating to https://www.mse.mk/mk/symbol/INEK...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - INEK - Инекс АД Горица Охрид
# Processed company name: Инекс АД Горица Охрид
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code INHO (ID: 49)...
# Navigating to https://www.mse.mk/mk/symbol/INHO...
# Detected 'issuer' in URL.
# Extracted company name: Интернешнел Хотелс АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code INOV (ID: 50)...
# Navigating to https://www.mse.mk/mk/symbol/INOV...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - INOV - Иново Брокер АД Скопје
# Processed company name: Иново Брокер АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code INPR (ID: 51)...
# Navigating to https://www.mse.mk/mk/symbol/INPR...
# Detected 'issuer' in URL.
# Extracted company name: Интерпромет АД Тетово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code INTP (ID: 52)...
# Navigating to https://www.mse.mk/mk/symbol/INTP...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - INTP - Капитал Банка АД Скопје
# Processed company name: Капитал Банка АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code JAKO (ID: 53)...
# Navigating to https://www.mse.mk/mk/symbol/JAKO...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - JAKO - Јавор Консалтинг Битола
# Processed company name: Јавор Консалтинг Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code JULI (ID: 54)...
# Navigating to https://www.mse.mk/mk/symbol/JULI...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - JULI - Палпласт АД Куманово
# Processed company name: Палпласт АД Куманово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code JUSK (ID: 55)...
# Navigating to https://www.mse.mk/mk/symbol/JUSK...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - JUSK - Југотутун Скопје
# Processed company name: Југотутун Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KARO (ID: 56)...
# Navigating to https://www.mse.mk/mk/symbol/KARO...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - KARO - Караорман Скопје
# Processed company name: Караорман Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KDFO (ID: 57)...
# Navigating to https://www.mse.mk/mk/symbol/KDFO...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - KDFO - НЛБ Фондови АД Скопје
# Processed company name: НЛБ Фондови АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KJUBI (ID: 58)...
# Navigating to https://www.mse.mk/mk/symbol/KJUBI...
# Detected 'issuer' in URL.
# Extracted company name: Македонија осигурување АД Скопје - Виена Иншуренс Груп
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KKFI (ID: 59)...
# Navigating to https://www.mse.mk/mk/symbol/KKFI...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - KKFI - МКК Еуроникел 2005 АД Кавадарци
# Processed company name: МКК Еуроникел 2005 АД Кавадарци
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KKST (ID: 60)...
# Navigating to https://www.mse.mk/mk/symbol/KKST...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - KKST - КК Струмица 2022 АД Струмица
# Processed company name: КК Струмица 2022 АД Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KLST (ID: 61)...
# Navigating to https://www.mse.mk/mk/symbol/KLST...
# Detected 'issuer' in URL.
# Extracted company name: Кланица со ладилник АД Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KMB (ID: 62)...
# Navigating to https://www.mse.mk/mk/symbol/KMB...
# Detected 'issuer' in URL.
# Extracted company name: Комерцијална банка АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KMPR (ID: 63)...
# Navigating to https://www.mse.mk/mk/symbol/KMPR...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - KMPR - Комунапроект Тетово
# Processed company name: Комунапроект Тетово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KOMU (ID: 64)...
# Navigating to https://www.mse.mk/mk/symbol/KOMU...
# Detected 'issuer' in URL.
# Extracted company name: ДС Смитх АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KONF (ID: 65)...
# Navigating to https://www.mse.mk/mk/symbol/KONF...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - KONF - Конзервна фабрика Струмица
# Processed company name: Конзервна фабрика Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KONZ (ID: 66)...
# Navigating to https://www.mse.mk/mk/symbol/KONZ...
# Detected 'issuer' in URL.
# Extracted company name: Фруктал Мак АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KORZ (ID: 67)...
# Navigating to https://www.mse.mk/mk/symbol/KORZ...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - KORZ - ЈАВОР Стоковна куќа КОРЗО АД Битола
# Processed company name: ЈАВОР Стоковна куќа КОРЗО АД Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KPSS (ID: 68)...
# Navigating to https://www.mse.mk/mk/symbol/KPSS...
# Detected 'issuer' in URL.
# Extracted company name: Фабрика Карпош АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KULT (ID: 69)...
# Navigating to https://www.mse.mk/mk/symbol/KULT...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - KULT - Култура Скопје
# Processed company name: Култура Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code KVAS (ID: 70)...
# Navigating to https://www.mse.mk/mk/symbol/KVAS...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - KVAS - Квасара АД Битола
# Processed company name: Квасара АД Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code LAJO (ID: 71)...
# Navigating to https://www.mse.mk/mk/symbol/LAJO...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - LAJO - Лајон Инс АД Скопје
# Processed company name: Лајон Инс АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code LHND (ID: 72)...
# Navigating to https://www.mse.mk/mk/symbol/LHND...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - LHND - Лихнида Охрид
# Processed company name: Лихнида Охрид
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code LOTO (ID: 73)...
# Navigating to https://www.mse.mk/mk/symbol/LOTO...
# Detected 'issuer' in URL.
# Extracted company name: Лотарија на Македонија АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code LOZP (ID: 74)...
# Navigating to https://www.mse.mk/mk/symbol/LOZP...
# Detected 'issuer' in URL.
# Extracted company name: Пелистерка АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MAGP (ID: 75)...
# Navigating to https://www.mse.mk/mk/symbol/MAGP...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - MAGP - ФК Македонија Ѓорче Петров - 1932 АД Скопје
# Processed company name: ФК Македонија Ѓорче Петров - 1932 АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MAKP (ID: 76)...
# Navigating to https://www.mse.mk/mk/symbol/MAKP...
# Detected 'issuer' in URL.
# Extracted company name: Макпромет АД Штип
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MAKS (ID: 77)...
# Navigating to https://www.mse.mk/mk/symbol/MAKS...
# Detected 'issuer' in URL.
# Extracted company name: Макотекс АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MB (ID: 78)...
# Navigating to https://www.mse.mk/mk/symbol/MB...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - MB - Македонска берза АД Скопје
# Processed company name: Македонска берза АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MERM (ID: 79)...
# Navigating to https://www.mse.mk/mk/symbol/MERM...
# Detected 'issuer' in URL.
# Extracted company name: Мермерен комбинат АД Прилеп
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MKSD (ID: 80)...
# Navigating to https://www.mse.mk/mk/symbol/MKSD...
# Detected 'issuer' in URL.
# Extracted company name: Макошпед АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MLKR (ID: 81)...
# Navigating to https://www.mse.mk/mk/symbol/MLKR...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - MLKR - Млекара Битола
# Processed company name: Млекара Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MODA (ID: 82)...
# Navigating to https://www.mse.mk/mk/symbol/MODA...
# Detected 'issuer' in URL.
# Extracted company name: Мода АД Свети Николе
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MPOL (ID: 83)...
# Navigating to https://www.mse.mk/mk/symbol/MPOL...
# Detected 'issuer' in URL.
# Extracted company name: Хотели Метропол Охрид
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MPT (ID: 84)...
# Navigating to https://www.mse.mk/mk/symbol/MPT...
# Detected 'issuer' in URL.
# Extracted company name: Макпетрол АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MPTE (ID: 85)...
# Navigating to https://www.mse.mk/mk/symbol/MPTE...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - MPTE - АД Макпетрол-Теас Скопје
# Processed company name: АД Макпетрол-Теас Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MTUR (ID: 86)...
# Navigating to https://www.mse.mk/mk/symbol/MTUR...
# Detected 'issuer' in URL.
# Extracted company name: Македонијатурист АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MZHE (ID: 87)...
# Navigating to https://www.mse.mk/mk/symbol/MZHE...
# Detected 'issuer' in URL.
# Extracted company name: Вабтек МЗТ АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code MZPU (ID: 88)...
# Navigating to https://www.mse.mk/mk/symbol/MZPU...
# Detected 'issuer' in URL.
# Extracted company name: МЗТ Пумпи АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code NEME (ID: 89)...
# Navigating to https://www.mse.mk/mk/symbol/NEME...
# Detected 'issuer' in URL.
# Extracted company name: Неметали Огражден АД Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code NOSK (ID: 90)...
# Navigating to https://www.mse.mk/mk/symbol/NOSK...
# Detected 'issuer' in URL.
# Extracted company name: Нова Стоковна куќа АД Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code OBPP (ID: 91)...
# Navigating to https://www.mse.mk/mk/symbol/OBPP...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - OBPP - Полиса плус Скопје
# Processed company name: Полиса плус Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code OILK (ID: 92)...
# Navigating to https://www.mse.mk/mk/symbol/OILK...
# Detected 'issuer' in URL.
# Extracted company name: ОИЛКО КДА Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code OKTA (ID: 93)...
# Navigating to https://www.mse.mk/mk/symbol/OKTA...
# Detected 'issuer' in URL.
# Extracted company name: ОКТА АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code OMOS (ID: 94)...
# Navigating to https://www.mse.mk/mk/symbol/OMOS...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - OMOS - Вега осигурување АД Скопје
# Processed company name: Вега осигурување АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code OPFO (ID: 95)...
# Navigating to https://www.mse.mk/mk/symbol/OPFO...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - OPFO - Опфолио АД Скопје
# Processed company name: Опфолио АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code OPTK (ID: 96)...
# Navigating to https://www.mse.mk/mk/symbol/OPTK...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - OPTK - Очна оптика Геталдус Скопје
# Processed company name: Очна оптика Геталдус Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ORAN (ID: 97)...
# Navigating to https://www.mse.mk/mk/symbol/ORAN...
# Detected 'issuer' in URL.
# Extracted company name: Оранжерии Хамзали Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code OSPO (ID: 98)...
# Navigating to https://www.mse.mk/mk/symbol/OSPO...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - OSPO - Осигурителна полиса АД Скопје
# Processed company name: Осигурителна полиса АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code OTEK (ID: 99)...
# Navigating to https://www.mse.mk/mk/symbol/OTEK...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - OTEK - Отекс Охрид
# Processed company name: Отекс Охрид
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code PELK (ID: 100)...
# Navigating to https://www.mse.mk/mk/symbol/PELK...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - PELK - Пелагонија комерц Битола
# Processed company name: Пелагонија комерц Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code PGGV (ID: 101)...
# Navigating to https://www.mse.mk/mk/symbol/PGGV...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - PGGV - Пелагонија Гостивар
# Processed company name: Пелагонија Гостивар
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code PKB (ID: 102)...
# Navigating to https://www.mse.mk/mk/symbol/PKB...
# Detected 'issuer' in URL.
# Extracted company name: Пекабеско АД Кадино Илинден
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code POPK (ID: 103)...
# Navigating to https://www.mse.mk/mk/symbol/POPK...
# Detected 'issuer' in URL.
# Extracted company name: Попова Кула АД Демир Капија
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code PPIV (ID: 104)...
# Navigating to https://www.mse.mk/mk/symbol/PPIV...
# Detected 'issuer' in URL.
# Extracted company name: Прилепска пиварница АД Прилеп
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code PROD (ID: 105)...
# Navigating to https://www.mse.mk/mk/symbol/PROD...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - PROD - ОП Просветно Дело Скопје
# Processed company name: ОП Просветно Дело Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code PROT (ID: 106)...
# Navigating to https://www.mse.mk/mk/symbol/PROT...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - PROT - Протектор АД Прилеп
# Processed company name: Протектор АД Прилеп
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code PTRS (ID: 107)...
# Navigating to https://www.mse.mk/mk/symbol/PTRS...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - PTRS - Роман АД Прилеп
# Processed company name: Роман АД Прилеп
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RADE (ID: 108)...
# Navigating to https://www.mse.mk/mk/symbol/RADE...
# Detected 'issuer' in URL.
# Extracted company name: Раде Кончар- Апаратна техника АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code REPL (ID: 109)...
# Navigating to https://www.mse.mk/mk/symbol/REPL...
# Detected 'issuer' in URL.
# Extracted company name: Реплек АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RIMI (ID: 110)...
# Navigating to https://www.mse.mk/mk/symbol/RIMI...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - RIMI - РИМИ АД Штип
# Processed company name: РИМИ АД Штип
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RINS (ID: 111)...
# Navigating to https://www.mse.mk/mk/symbol/RINS...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - RINS - Реинг АД Скопје
# Processed company name: Реинг АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RZEK (ID: 112)...
# Navigating to https://www.mse.mk/mk/symbol/RZEK...
# Detected 'issuer' in URL.
# Extracted company name: РЖ Економика АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RZIT (ID: 113)...
# Navigating to https://www.mse.mk/mk/symbol/RZIT...
# Detected 'issuer' in URL.
# Extracted company name: РЖ Интер-Трансшпед АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RZIZ (ID: 114)...
# Navigating to https://www.mse.mk/mk/symbol/RZIZ...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - RZIZ - РЖ Инжинеринг Скопје
# Processed company name: РЖ Инжинеринг Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RZLE (ID: 115)...
# Navigating to https://www.mse.mk/mk/symbol/RZLE...
# Detected 'issuer' in URL.
# Extracted company name: АрцелорМиттал (ХРМ) АД Скопје - долгорочно суспендирано од котација
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RZLV (ID: 116)...
# Navigating to https://www.mse.mk/mk/symbol/RZLV...
# Detected 'issuer' in URL.
# Extracted company name: Либерти АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RZTK (ID: 117)...
# Navigating to https://www.mse.mk/mk/symbol/RZTK...
# Detected 'issuer' in URL.
# Extracted company name: РЖ Техничка Контрола АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RZUG (ID: 118)...
# Navigating to https://www.mse.mk/mk/symbol/RZUG...
# Detected 'issuer' in URL.
# Extracted company name: Уготур АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code RZUS (ID: 119)...
# Navigating to https://www.mse.mk/mk/symbol/RZUS...
# Detected 'issuer' in URL.
# Extracted company name: РЖ Услуги АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SBT (ID: 120)...
# Navigating to https://www.mse.mk/mk/symbol/SBT...
# Detected 'issuer' in URL.
# Extracted company name: Стопанска банка АД Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SDOM (ID: 121)...
# Navigating to https://www.mse.mk/mk/symbol/SDOM...
# Detected 'issuer' in URL.
# Extracted company name: Современ дом АД Прилеп
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SIL (ID: 122)...
# Navigating to https://www.mse.mk/mk/symbol/SIL...
# Detected 'issuer' in URL.
# Extracted company name: Силекс АД Кратово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SKON (ID: 123)...
# Navigating to https://www.mse.mk/mk/symbol/SKON...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - SKON - Индустријал Струма АД Струмица
# Processed company name: Индустријал Струма АД Струмица
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SKP (ID: 124)...
# Navigating to https://www.mse.mk/mk/symbol/SKP...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - SKP - Пивара Скопје АД Скопје
# Processed company name: Пивара Скопје АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SLAV (ID: 125)...
# Navigating to https://www.mse.mk/mk/symbol/SLAV...
# Detected 'issuer' in URL.
# Extracted company name: Славеј АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SNBT (ID: 126)...
# Navigating to https://www.mse.mk/mk/symbol/SNBT...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - SNBT - СН Осигурителен брокер АД Битола
# Processed company name: СН Осигурителен брокер АД Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SNBTO (ID: 127)...
# Navigating to https://www.mse.mk/mk/symbol/SNBTO...
# Detected 'issuer' in URL.
# Extracted company name: СН Осигурителен Брокер АД Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SOLN (ID: 128)...
# Navigating to https://www.mse.mk/mk/symbol/SOLN...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - SOLN - Солун - 2001 Гевгелија
# Processed company name: Солун - 2001 Гевгелија
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SPAZ (ID: 129)...
# Navigating to https://www.mse.mk/mk/symbol/SPAZ...
# Detected 'issuer' in URL.
# Extracted company name: Скопски Пазар АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SPAZP (ID: 130)...
# Navigating to https://www.mse.mk/mk/symbol/SPAZP...
# Detected 'issuer' in URL.
# Extracted company name: Скопски Пазар АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SPOL (ID: 131)...
# Navigating to https://www.mse.mk/mk/symbol/SPOL...
# Detected 'issuer' in URL.
# Extracted company name: Струмичко поле с. Василево
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code SSPR (ID: 132)...
# Navigating to https://www.mse.mk/mk/symbol/SSPR...
# Detected 'issuer' in URL.
# Extracted company name: Сигурносно стакло АД Прилеп
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code STB (ID: 133)...
# Navigating to https://www.mse.mk/mk/symbol/STB...
# Detected 'issuer' in URL.
# Extracted company name: Стопанска банка АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code STBP (ID: 134)...
# Navigating to https://www.mse.mk/mk/symbol/STBP...
# Detected 'issuer' in URL.
# Extracted company name: Стопанска банка АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code STIL (ID: 135)...
# Navigating to https://www.mse.mk/mk/symbol/STIL...
# Detected 'issuer' in URL.
# Extracted company name: Макстил АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code STOK (ID: 136)...
# Navigating to https://www.mse.mk/mk/symbol/STOK...
# Detected 'issuer' in URL.
# Extracted company name: Стокопромет АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TAJM (ID: 137)...
# Navigating to https://www.mse.mk/mk/symbol/TAJM...
# Detected 'issuer' in URL.
# Extracted company name: Тајмиште АД Кичево - долгорочно суспендирано од котација
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TASK (ID: 138)...
# Navigating to https://www.mse.mk/mk/symbol/TASK...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - TASK - Таска АД Кавадарци
# Processed company name: Таска АД Кавадарци
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TBKO (ID: 139)...
# Navigating to https://www.mse.mk/mk/symbol/TBKO...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - TBKO - Сава Табак Осигурување Скопје
# Processed company name: Сава Табак Осигурување Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TEAL (ID: 140)...
# Navigating to https://www.mse.mk/mk/symbol/TEAL...
# Detected 'issuer' in URL.
# Extracted company name: ТЕАЛ АД Тетово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TEHN (ID: 141)...
# Navigating to https://www.mse.mk/mk/symbol/TEHN...
# Detected 'issuer' in URL.
# Extracted company name: Технокомерц АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TEL (ID: 142)...
# Navigating to https://www.mse.mk/mk/symbol/TEL...
# Detected 'issuer' in URL.
# Extracted company name: Македонски Телеком АД – Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TETE (ID: 143)...
# Navigating to https://www.mse.mk/mk/symbol/TETE...
# Detected 'issuer' in URL.
# Extracted company name: Тетекс АД Тетово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TIGA (ID: 144)...
# Navigating to https://www.mse.mk/mk/symbol/TIGA...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - TIGA - Тигар Крива Паланка
# Processed company name: Тигар Крива Паланка
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TIKV (ID: 145)...
# Navigating to https://www.mse.mk/mk/symbol/TIKV...
# Detected 'issuer' in URL.
# Extracted company name: ГД-ТИКВЕШ АД Кавадарци
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TKPR (ID: 146)...
# Navigating to https://www.mse.mk/mk/symbol/TKPR...
# Detected 'issuer' in URL.
# Extracted company name: Тутунски комбинат АД Прилеп
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TKVS (ID: 147)...
# Navigating to https://www.mse.mk/mk/symbol/TKVS...
# Detected 'issuer' in URL.
# Extracted company name: ВВ Тиквеш АД Кавадарци
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TNB (ID: 148)...
# Navigating to https://www.mse.mk/mk/symbol/TNB...
# Detected 'issuer' in URL.
# Extracted company name: НЛБ Банка АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TRDB (ID: 149)...
# Navigating to https://www.mse.mk/mk/symbol/TRDB...
# Detected 'issuer' in URL.
# Extracted company name: Трудбеник АД Охрид - долгорочно суспендирано од котација
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TRPS (ID: 150)...
# Navigating to https://www.mse.mk/mk/symbol/TRPS...
# Detected 'issuer' in URL.
# Extracted company name: Патнички сообраќај Транскоп АД Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TRUB (ID: 151)...
# Navigating to https://www.mse.mk/mk/symbol/TRUB...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - TRUB - Факултетско земјоделско стопанство с.Трубарево
# Processed company name: Факултетско земјоделско стопанство с.Трубарево
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TSMP (ID: 152)...
# Navigating to https://www.mse.mk/mk/symbol/TSMP...
# Detected 'issuer' in URL.
# Extracted company name: Трготекстил Малопродажба АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TSZS (ID: 153)...
# Navigating to https://www.mse.mk/mk/symbol/TSZS...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - TSZS - Трготекстил заед. служ. Скопје
# Processed company name: Трготекстил заед. служ. Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code TTK (ID: 154)...
# Navigating to https://www.mse.mk/mk/symbol/TTK...
# Detected 'issuer' in URL.
# Extracted company name: ТТК Банка АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code UNI (ID: 155)...
# Navigating to https://www.mse.mk/mk/symbol/UNI...
# Detected 'issuer' in URL.
# Extracted company name: УНИ Банка АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code USJE (ID: 156)...
# Navigating to https://www.mse.mk/mk/symbol/USJE...
# Detected 'issuer' in URL.
# Extracted company name: Цементарница УСЈЕ АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code VARG (ID: 157)...
# Navigating to https://www.mse.mk/mk/symbol/VARG...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - VARG - АД Вардар Градско
# Processed company name: АД Вардар Градско
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code VFPM (ID: 158)...
# Navigating to https://www.mse.mk/mk/symbol/VFPM...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - VFPM - ВФП МЕНАЏМЕНТ АД Скопје
# Processed company name: ВФП МЕНАЏМЕНТ АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code VITA (ID: 159)...
# Navigating to https://www.mse.mk/mk/symbol/VITA...
# Detected 'issuer' in URL.
# Extracted company name: Витаминка АД Прилеп
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code VROS (ID: 160)...
# Navigating to https://www.mse.mk/mk/symbol/VROS...
# Detected 'issuer' in URL.
# Extracted company name: Триглав Осигурување АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code VSC (ID: 161)...
# Navigating to https://www.mse.mk/mk/symbol/VSC...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - VSC - Ветеринарно сточарски центар АД Куманово
# Processed company name: Ветеринарно сточарски центар АД Куманово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code VTKS (ID: 162)...
# Navigating to https://www.mse.mk/mk/symbol/VTKS...
# Detected 'issuer' in URL.
# Extracted company name: Ветекс АД Велес
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ZAS (ID: 163)...
# Navigating to https://www.mse.mk/mk/symbol/ZAS...
# Detected 'issuer' in URL.
# Extracted company name: ЖАС АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ZILU (ID: 164)...
# Navigating to https://www.mse.mk/mk/symbol/ZILU...
# Detected 'issuer' in URL.
# Extracted company name: Жито Лукс АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ZILUP (ID: 165)...
# Navigating to https://www.mse.mk/mk/symbol/ZILUP...
# Detected 'issuer' in URL.
# Extracted company name: Жито Лукс АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ZIMS (ID: 166)...
# Navigating to https://www.mse.mk/mk/symbol/ZIMS...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - ZIMS - ЗИМ СКОПЈЕ АД Скопје
# Processed company name: ЗИМ СКОПЈЕ АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ZKAR (ID: 167)...
# Navigating to https://www.mse.mk/mk/symbol/ZKAR...
# Detected 'issuer' in URL.
# Extracted company name: Жито Караорман АД Кичево
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ZPKO (ID: 168)...
# Navigating to https://www.mse.mk/mk/symbol/ZPKO...
# Detected 'issuer' in URL.
# Extracted company name: ЗК Пелагонија АД Битола
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ZPOG (ID: 169)...
# Navigating to https://www.mse.mk/mk/symbol/ZPOG...
# Detected 'issuer' in URL.
# Extracted company name: Жито Полог АД Тетово
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ZSIL (ID: 170)...
# Navigating to https://www.mse.mk/mk/symbol/ZSIL...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - ZSIL - ЗС Илинден Скопје
# Processed company name: ЗС Илинден Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Processing company code ZUAS (ID: 171)...
# Navigating to https://www.mse.mk/mk/symbol/ZUAS...
# No 'issuer' in URL. Attempting alternative structure...
# Raw company name: Шифра на ХВ - ZUAS - ЗУАС АД Скопје
# Processed company name: ЗУАС АД Скопје
# Saving data to: C:\Users\matej\Desktop\dias_project\stock_predictor\stockapp\data\company_codes_and_names.csv
# Web driver closed.
